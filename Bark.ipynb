# %% [markdown]
# ## Install

# %%
# install bark (make sure you have torch>=2 for much faster flash-attention)
# %pip install git+https://github.com/suno-ai/bark.git
# Out:
# Collecting git+https://github.com/suno-ai/bark.git
#   Cloning https://github.com/suno-ai/bark.git to /tmp/pip-req-build-k2xpas_r
#   Running command git clone --filter=blob:none --quiet https://github.com/suno-ai/bark.git /tmp/pip-req-build-k2xpas_r
#   Resolved https://github.com/suno-ai/bark.git to commit 773624d26db84278a55aacae9a16d7b25fbccab8
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting encodec
#   Downloading encodec-0.1.1.tar.gz (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 14.7 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting numpy
#   Downloading numpy-1.26.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 29.0 MB/s eta 0:00:0000:0100:01
# Collecting transformers
#   Downloading transformers-4.36.2-py3-none-any.whl (8.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 30.7 MB/s eta 0:00:00a 0:00:01
# Collecting scipy
#   Downloading scipy-1.11.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 28.2 MB/s eta 0:00:0000:0100:01
# Collecting tqdm
#   Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# Collecting torch
#   Downloading torch-2.1.2-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 11.1 MB/s eta 0:00:0000:0100:01
# Collecting funcy
#   Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Collecting huggingface-hub>=0.14.1
#   Downloading huggingface_hub-0.20.2-py3-none-any.whl (330 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 330.3/330.3 KB 35.2 MB/s eta 0:00:00
# Collecting boto3
#   Downloading boto3-1.34.18-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 KB 13.7 MB/s eta 0:00:00
# Collecting tokenizers
#   Downloading tokenizers-0.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 26.2 MB/s eta 0:00:0000:0100:01
# Collecting requests
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting pyyaml>=5.1
#   Using cached PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
# Collecting filelock
#   Using cached filelock-3.13.1-py3-none-any.whl (11 kB)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2023.12.2-py3-none-any.whl (168 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.0/169.0 KB 28.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.9 in ./.env/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (23.2)
# Collecting typing-extensions>=3.7.4.3
#   Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Collecting botocore<1.35.0,>=1.34.18
#   Downloading botocore-1.34.18-py3-none-any.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 29.6 MB/s eta 0:00:0000:0100:01
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0
#   Downloading s3transfer-0.10.0-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 KB 33.2 MB/s eta 0:00:00
# Collecting einops
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 KB 11.4 MB/s eta 0:00:00
# Collecting torchaudio
#   Downloading torchaudio-2.1.2-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 29.7 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cufft-cu12==11.0.2.54
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 14.0 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cublas-cu12==12.1.3.1
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 11.9 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-runtime-cu12==12.1.105
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 KB 23.3 MB/s eta 0:00:0000:01
# Collecting sympy
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 21.2 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cudnn-cu12==8.9.2.26
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 9.2 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 30.5 MB/s eta 0:00:0000:0100:01
# Collecting networkx
#   Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 19.3 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nccl-cu12==2.18.1
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 15.0 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvtx-cu12==12.1.105
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 KB 29.4 MB/s eta 0:00:00
# Collecting triton==2.1.0
#   Downloading triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 24.0 MB/s eta 0:00:0000:0100:01
# Collecting jinja2
#   Downloading Jinja2-3.1.3-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.2/133.2 KB 34.5 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 30.2 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-curand-cu12==10.3.2.106
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 26.4 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusolver-cu12==11.4.5.107
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 19.7 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-nvjitlink-cu12
#   Downloading nvidia_nvjitlink_cu12-12.3.101-py3-none-manylinux1_x86_64.whl (20.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 27.3 MB/s eta 0:00:0000:0100:01
# Collecting regex!=2019.12.17
#   Downloading regex-2023.12.25-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (773 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 774.0/774.0 KB 30.4 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1
#   Downloading safetensors-0.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 27.3 MB/s eta 0:00:00a 0:00:01
# Collecting urllib3<2.1,>=1.25.4
#   Using cached urllib3-2.0.7-py3-none-any.whl (124 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in ./.env/lib/python3.10/site-packages (from botocore<1.35.0,>=1.34.18->boto3->suno-bark==0.0.1a0) (2.8.2)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2023.11.17-py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 KB 41.8 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.6-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 KB 18.8 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 KB 24.0 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in ./.env/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.18->boto3->suno-bark==0.0.1a0) (1.16.0)
# Using legacy 'setup.py install' for encodec, since package 'wheel' is not installed.
# Building wheels for collected packages: suno-bark
#   Building wheel for suno-bark (pyproject.toml) ... done
#   Created wheel for suno-bark: filename=suno_bark-0.0.1a0-py3-none-any.whl size=2567413 sha256=81c75e0c7cc6f401def96aa101be105685dc6ba490b9228d399d18e6044b1a74
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6pkoq5pk/wheels/e6/6d/c2/107ed849afe600f905bb4049a026df3c7c5aa75d86c2721ec7
# Successfully built suno-bark
# Installing collected packages: mpmath, funcy, urllib3, typing-extensions, tqdm, sympy, safetensors, regex, pyyaml, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, jmespath, idna, fsspec, filelock, einops, charset-normalizer, certifi, triton, scipy, requests, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, botocore, s3transfer, nvidia-cusolver-cu12, huggingface-hub, torch, tokenizers, boto3, transformers, torchaudio, encodec, suno-bark
#   Running setup.py install for encodec ... done
# Successfully installed MarkupSafe-2.1.3 boto3-1.34.18 botocore-1.34.18 certifi-2023.11.17 charset-normalizer-3.3.2 einops-0.7.0 encodec-0.1.1 filelock-3.13.1 fsspec-2023.12.2 funcy-2.0 huggingface-hub-0.20.2 idna-3.6 jinja2-3.1.3 jmespath-1.0.1 mpmath-1.3.0 networkx-3.2.1 numpy-1.26.3 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.3.101 nvidia-nvtx-cu12-12.1.105 pyyaml-6.0.1 regex-2023.12.25 requests-2.31.0 s3transfer-0.10.0 safetensors-0.4.1 scipy-1.11.4 suno-bark-0.0.1a0 sympy-1.12 tokenizers-0.15.0 torch-2.1.2 torchaudio-2.1.2 tqdm-4.66.1 transformers-4.36.2 triton-2.1.0 typing-extensions-4.9.0 urllib3-2.0.7
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pydub
# Out:
# Collecting pydub
#   Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Installing collected packages: pydub
# Successfully installed pydub-0.25.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install SpeechRecognition
# Out:
# Collecting SpeechRecognition
#   Downloading SpeechRecognition-3.10.1-py2.py3-none-any.whl (32.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 29.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: requests>=2.26.0 in ./.env/lib/python3.10/site-packages (from SpeechRecognition) (2.31.0)
# Requirement already satisfied: typing-extensions in ./.env/lib/python3.10/site-packages (from SpeechRecognition) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.env/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.env/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (2023.11.17)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.env/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in ./.env/lib/python3.10/site-packages (from requests>=2.26.0->SpeechRecognition) (3.6)
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.10.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U git+https://github.com/jianfch/stable-ts.git
# Out:
# Collecting git+https://github.com/jianfch/stable-ts.git
#   Cloning https://github.com/jianfch/stable-ts.git to /tmp/pip-req-build-udj6r9qt
#   Running command git clone --filter=blob:none --quiet https://github.com/jianfch/stable-ts.git /tmp/pip-req-build-udj6r9qt
#   Resolved https://github.com/jianfch/stable-ts.git to commit 677f233bedff857b56bfe48e10d095c40d7f6425
#   Preparing metadata (setup.py) ... done
# Collecting ffmpeg-python==0.2.0
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Collecting more-itertools
#   Downloading more_itertools-10.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 KB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in ./.env/lib/python3.10/site-packages (from stable-ts==2.14.3) (1.26.3)
# Collecting openai-whisper==20231117
#   Downloading openai-whisper-20231117.tar.gz (798 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.6/798.6 KB 12.8 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch in ./.env/lib/python3.10/site-packages (from stable-ts==2.14.3) (2.1.2)
# Requirement already satisfied: torchaudio in ./.env/lib/python3.10/site-packages (from stable-ts==2.14.3) (2.1.2)
# Requirement already satisfied: tqdm in ./.env/lib/python3.10/site-packages (from stable-ts==2.14.3) (4.66.1)
# Requirement already satisfied: transformers>=4.19.0 in ./.env/lib/python3.10/site-packages (from stable-ts==2.14.3) (4.36.2)
# Collecting future
#   Using cached future-0.18.3.tar.gz (840 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tiktoken
#   Downloading tiktoken-0.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 30.4 MB/s eta 0:00:00a 0:00:01
# Collecting numba
#   Using cached numba-0.58.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
# Requirement already satisfied: triton<3,>=2.0.0 in ./.env/lib/python3.10/site-packages (from openai-whisper==20231117->stable-ts==2.14.3) (2.1.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in ./.env/lib/python3.10/site-packages (from transformers>=4.19.0->stable-ts==2.14.3) (0.20.2)
# Requirement already satisfied: pyyaml>=5.1 in ./.env/lib/python3.10/site-packages (from transformers>=4.19.0->stable-ts==2.14.3) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in ./.env/lib/python3.10/site-packages (from transformers>=4.19.0->stable-ts==2.14.3) (2023.12.25)
# Requirement already satisfied: safetensors>=0.3.1 in ./.env/lib/python3.10/site-packages (from transformers>=4.19.0->stable-ts==2.14.3) (0.4.1)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in ./.env/lib/python3.10/site-packages (from transformers>=4.19.0->stable-ts==2.14.3) (0.15.0)
# Requirement already satisfied: requests in ./.env/lib/python3.10/site-packages (from transformers>=4.19.0->stable-ts==2.14.3) (2.31.0)
# Requirement already satisfied: packaging>=20.0 in ./.env/lib/python3.10/site-packages (from transformers>=4.19.0->stable-ts==2.14.3) (23.2)
# Requirement already satisfied: filelock in ./.env/lib/python3.10/site-packages (from transformers>=4.19.0->stable-ts==2.14.3) (3.13.1)
# Requirement already satisfied: jinja2 in ./.env/lib/python3.10/site-packages (from torch->stable-ts==2.14.3) (3.1.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.env/lib/python3.10/site-packages (from torch->stable-ts==2.14.3) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.env/lib/python3.10/site-packages (from torch->stable-ts==2.14.3) (8.9.2.26)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in ./.env/lib/python3.10/site-packages (from torch->stable-ts==2.14.3) (2.18.1)
# Requirement already satisfied: sympy in ./.env/lib/python3.10/site-packages (from torch->stable-ts==2.14.3) (1.12)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.env/lib/python3.10/site-packages (from torch->stable-ts==2.14.3) (12.1.105)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.env/lib/python3.10/site-packages (from torch->stable-ts==2.14.3) (11.4.5.107)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.env/lib/python3.10/site-packages (from torch->stable-ts==2.14.3) (12.1.105)
# Requirement already satisfied: networkx in ./.env/lib/python3.10/site-packages (from torch->stable-ts==2.14.3) (3.2.1)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.env/lib/python3.10/site-packages (from torch->stable-ts==2.14.3) (12.1.0.106)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.env/lib/python3.10/site-packages (from torch->stable-ts==2.14.3) (10.3.2.106)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.env/lib/python3.10/site-packages (from torch->stable-ts==2.14.3) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.env/lib/python3.10/site-packages (from torch->stable-ts==2.14.3) (11.0.2.54)
# Requirement already satisfied: typing-extensions in ./.env/lib/python3.10/site-packages (from torch->stable-ts==2.14.3) (4.9.0)
# Requirement already satisfied: fsspec in ./.env/lib/python3.10/site-packages (from torch->stable-ts==2.14.3) (2023.12.2)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.env/lib/python3.10/site-packages (from torch->stable-ts==2.14.3) (12.1.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.env/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->stable-ts==2.14.3) (12.3.101)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.env/lib/python3.10/site-packages (from jinja2->torch->stable-ts==2.14.3) (2.1.3)
# Collecting llvmlite<0.42,>=0.41.0dev0
#   Using cached llvmlite-0.41.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.6 MB)
# Requirement already satisfied: certifi>=2017.4.17 in ./.env/lib/python3.10/site-packages (from requests->transformers>=4.19.0->stable-ts==2.14.3) (2023.11.17)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.env/lib/python3.10/site-packages (from requests->transformers>=4.19.0->stable-ts==2.14.3) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.env/lib/python3.10/site-packages (from requests->transformers>=4.19.0->stable-ts==2.14.3) (2.0.7)
# Requirement already satisfied: idna<4,>=2.5 in ./.env/lib/python3.10/site-packages (from requests->transformers>=4.19.0->stable-ts==2.14.3) (3.6)
# Requirement already satisfied: mpmath>=0.19 in ./.env/lib/python3.10/site-packages (from sympy->torch->stable-ts==2.14.3) (1.3.0)
# Using legacy 'setup.py install' for stable-ts, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for future, since package 'wheel' is not installed.
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=801356 sha256=0a51205bbb9e1bec52b094c8d0d96a1808d30d6e761372cd088cc80edd2a05ca
#   Stored in directory: /home/alvaro/.cache/pip/wheels/d0/85/e1/9361b4cbea7dd4b7f6702fa4c3afc94877952eeb2b62f45f56
# Successfully built openai-whisper
# Installing collected packages: more-itertools, llvmlite, future, tiktoken, numba, ffmpeg-python, openai-whisper, stable-ts
#   Running setup.py install for future ... done
#   Running setup.py install for stable-ts ... done
# Successfully installed ffmpeg-python-0.2.0 future-0.18.3 llvmlite-0.41.1 more-itertools-10.2.0 numba-0.58.1 openai-whisper-20231117 stable-ts-2.14.3 tiktoken-0.5.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Read Chistes

# %%
import pandas as pd

# %%
df_chistes = pd.read_csv('chistes_con_metadatos.csv')

# %% [markdown]
# ## Long text generator

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "0"


from IPython.display import Audio
import nltk  # we'll use this to split into sentences
import numpy as np

from bark.generation import (
    generate_text_semantic,
    preload_models,
)
from bark.api import semantic_to_waveform
from bark import generate_audio, SAMPLE_RATE

nltk.download('punkt')

from scipy.io.wavfile import write
from pydub import AudioSegment
from pydub import effects
# Out:
# [nltk_data] Downloading package punkt to /home/alvaro/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
preload_models()
# Out:
# text_2.pt: 100%|██████████| 5.35G/5.35G [02:34<00:00, 34.6MB/s]
# tokenizer_config.json: 100%|██████████| 29.0/29.0 [00:00<00:00, 207kB/s]
# vocab.txt: 100%|██████████| 996k/996k [00:00<00:00, 4.59MB/s]
# tokenizer.json: 100%|██████████| 1.96M/1.96M [00:00<00:00, 5.82MB/s]
# config.json: 100%|██████████| 625/625 [00:00<00:00, 1.66MB/s]
# coarse_2.pt: 100%|██████████| 3.93G/3.93G [01:51<00:00, 35.1MB/s]
# fine_2.pt: 100%|██████████| 3.74G/3.74G [01:45<00:00, 35.6MB/s]
# /home/alvaro/tuchistediario_local/TuChisteDiario/.env/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# Downloading: "https://dl.fbaipublicfiles.com/encodec/v0/encodec_24khz-d7cc33bc.th" to /home/alvaro/.cache/torch/hub/checkpoints/encodec_24khz-d7cc33bc.th
# 100%|██████████| 88.9M/88.9M [00:02<00:00, 37.9MB/s]

# %%
import stable_whisper
model = stable_whisper.load_model('medium')
# Out:
# 100%|█████████████████████████████████████| 1.42G/1.42G [02:34<00:00, 9.87MiB/s]

# %%
def agrupar_subtitulos(nombre_archivo, nombre_salida, num_palabras):
    try:
        with open(nombre_archivo, 'r', encoding='utf-8') as archivo:
            lineas = archivo.readlines()

            subtitulos = []
            tiempos = []
            texto_subtitulo = ""
            tiempo_actual = ""

            for linea in lineas:
                linea = linea.strip()
                if not linea:
                    subtitulos.append(texto_subtitulo.strip())
                    tiempos.append(tiempo_actual)
                    texto_subtitulo = ""
                    tiempo_actual = ""
                elif "-->" in linea:
                    tiempo_actual = linea
                elif not linea.isdigit():
                    texto_subtitulo += linea + " "

            subtitulos.append(texto_subtitulo.strip())
            tiempos.append(tiempo_actual)

            subtitulos_agrupados = []
            tiempos_agrupados = []
            texto_agrupado = ""
            contador_palabras = 0
            tiempo_inicio = tiempos[0].split(" --> ")[0]
            for i, subtitulo in enumerate(subtitulos):
                palabras = subtitulo.split()
                contador_palabras += len(palabras)
                texto_agrupado += subtitulo + " "
                if contador_palabras >= num_palabras or i == len(subtitulos) - 1:
                    tiempo_fin = tiempos[i].split(" --> ")[1]
                    subtitulos_agrupados.append(texto_agrupado.strip())
                    tiempos_agrupados.append(tiempo_inicio + " --> " + tiempo_fin)
                    texto_agrupado = ""
                    contador_palabras = 0
                    if i+1 < len(tiempos):
                        tiempo_inicio = tiempos[i+1].split(" --> ")[0]

            with open(nombre_salida, 'w', encoding='utf-8') as salida:
                for i, (tiempo, subtitulo) in enumerate(zip(tiempos_agrupados, subtitulos_agrupados)):
                    salida.write(f"{i}\n")
                    salida.write(tiempo + "\n")
                    salida.write(subtitulo + "\n\n")

    except FileNotFoundError:
        print(f"No se pudo encontrar el archivo {nombre_archivo}")
    except Exception as e:
        print(f"Se produjo un error: {e}")

# %%
# Risa enlatada
risa_enlatada = AudioSegment.from_wav("risas.wav")
# Chistes a crear
df_chistes_crear = df_chistes[~df_chistes['audio_creado']]

for index, row in df_chistes_crear.iterrows():

  print(f"-----------------------------")
  print(f"------ Chiste {index} -------")
  print(f"-----------------------------")

  text_prompt = row['text']
  print(f"Chiste: {text_prompt}")

  #creo carpeta del chiste
  path = f"audios_chistes/chiste_{index}"
  if os.path.exists(path):
    # %rm -r {path}
  os.makedirs(path)
  print('100%|██████████| carpeta creada')

  for genero in ['masc','fem']:

    print(f"-> Chiste {index} {genero}")

    text_prompt = row['text']
    text_prompt = text_prompt.replace("...","").replace("- ","-")
    script = text_prompt.replace("\n", " ").strip()
    sentences = nltk.sent_tokenize(script)

    SPEAKER = "es_speaker_7" if genero == 'masc' else "v2/es_speaker_9"
    NAME_AUDIO = "/audio_" + genero
    NAME_SRT = "/subs_" + genero
    silence = np.zeros(int(0.2 * SAMPLE_RATE))  # quarter second of silence

    pieces = []
    for sentence in sentences:
        audio_array = generate_audio(sentence, history_prompt=SPEAKER)
        pieces += [audio_array, silence.copy()]

    audio = np.concatenate(pieces)
    # Escalar y convertir el array a formato entero de 16 bits
    scaled_audio = np.int16(audio * 32767.0)
    ruta_resultado = path + "/temp_chiste"
    write(ruta_resultado, SAMPLE_RATE, scaled_audio)

    #Aumentar velocidad
    velocidad_X = 1.2 # No puede estar por debajo de 1.0
    sound = AudioSegment.from_file(ruta_resultado)
    os.remove(ruta_resultado)
    so = sound.speedup(velocidad_X, 150, 25)
    ruta_resultado = path + "/temp_chiste_speedup"
    so.export(ruta_resultado, format="wav")
    print(f"100%|██████████| velocidad {velocidad_X}")

    # Crear Subtitulos
    result = model.transcribe(ruta_resultado)
    result.to_srt_vtt(path + NAME_SRT + '_words.srt', segment_level=False, word_level=True)
    agrupar_subtitulos(path + NAME_SRT + '_words.srt',path + NAME_SRT + '.srt', 4)
    print('100%|██████████| subtítulos creados')

    # Crear Risas
    audio_existente = AudioSegment.from_wav(ruta_resultado)
    os.remove(ruta_resultado)
    audio_final = audio_existente + risa_enlatada
    ruta_resultado = path + NAME_AUDIO
    audio_final.export(ruta_resultado, format="wav")
    print('100%|██████████| risas concatenadas')

  #marcamos chiste como creado
  df_chistes.loc[index,'audio_creado'] = True
  df_chistes.to_csv('chistes_con_metadatos.csv',index=False)
